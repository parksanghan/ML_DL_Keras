# %%
import gdown
gdown.download('https://bit.ly/3pK7iuu', 'ns_book7.csv', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3pK7iuu
# To: /content/ns_book7.csv
# 100%|██████████| 53.8M/53.8M [00:00<00:00, 94.8MB/s]
# 'ns_book7.csv'

# %%
import pandas as pd

ns_book7 = pd.read_csv('ns_book7.csv', low_memory=False)
ns_book7.ISBN = ns_book7.ISBN.astype(str)
ns_book7.ISBN
# Out:
# 0         9788937444319
# 1         9791190123969
# 2         9788968332982
# 3         9788970759906
# 4         9788934990833
#               ...
# 376765    9788942340262
# 376766    9788974231323
# 376767    9788977352971
# 376768    9788985367448
# 376769    9788947700368
# Name: ISBN, Length: 376770, dtype: object

# %%
ns_book7.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
ns_book7["도서명"]
# Out:
# 0                       인공지능과 흙
# 1                  가짜 행복 권하는 사회
# 2         나도 한 문장 잘 쓰면 바랄 게 없겠네
# 3                       예루살렘 해변
# 4         김성곤의 중국한시기행 : 장강·황하 편
#                   ...
# 376765              소설의 사회사 비교론
# 376766                      큰오빠
# 376767                  韓國現代詩大系
# 376768                    뉴 웨이브
# 376769             독일 문학과 세계 문학
# Name: 도서명, Length: 376770, dtype: object

# %%
ns_book7.도서명
# Out:
# 0                       인공지능과 흙
# 1                  가짜 행복 권하는 사회
# 2         나도 한 문장 잘 쓰면 바랄 게 없겠네
# 3                       예루살렘 해변
# 4         김성곤의 중국한시기행 : 장강·황하 편
#                   ...
# 376765              소설의 사회사 비교론
# 376766                      큰오빠
# 376767                  韓國現代詩大系
# 376768                    뉴 웨이브
# 376769             독일 문학과 세계 문학
# Name: 도서명, Length: 376770, dtype: object

# %%
count_By_year =ns_book7.발행년도.value_counts()

# %%
count_By_year.sort_index()
# Out:
# 발행년도
# 1947     1
# 1948     1
# 1949     1
# 1952    11
# 1954     1
#         ..
# 2551     1
# 2552     2
# 2559     1
# 2560     1
# 2650     1
# Name: count, Length: 87, dtype: int64

# %%
count_By_year.sort_values()
# Out:
# 발행년도
# 1947        1
# 1954        1
# 1965        1
# 2548        1
# 1948        1
#         ...
# 2010    17503
# 2011    17523
# 2009    17611
# 2014    17797
# 2012    18601
# Name: count, Length: 87, dtype: int64

# %%
count_By_year = count_By_year[(count_By_year <= 2030) & (count_By_year >= 1900)]
count_By_year
# Out:
# 발행년도
# 1992    1932
# Name: count, dtype: int64

# %%
import numpy as np
def filter_char(no):
  if no is np.nan:
    return "-1"
  else:
    return no[0]

# %%
count_by_subject = ns_book7['주제분류번호'].apply(filter_char).value_counts()
count_by_subject
# Out:
# 주제분류번호
# 8     108643
# 3      80767
# 5      40916
# 9      26375
# 6      25070
# 1      22647
# -1     16978
# 7      15836
# 4      13688
# 2      13474
# 0      12376
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 100

# %%
plt.plot(count_by_year.index, count_by_year.values)
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
plt.show()

# %%
plt.plot(count_by_year, marker='.', linestyle=':', color='red')
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
plt.show()

# %%
plt.plot(count_by_year, '*-y')
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
plt.show()

# %%
plt.plot(count_by_year, '*-g')
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
plt.xticks(range(1947, 2030, 10))
for idx, val in count_by_year[::5].items():
    plt.annotate(val, (idx, val))
plt.show()

# %% [markdown]
# 대 그래프 그리기

# %%
plt.bar(count_by_subject.index, count_by_subject.values)
plt.title('Books by subject')
plt.xlabel('subject')
plt.ylabel('number of books')
for idx, val in count_by_subject.items():
    plt.annotate(val, (idx, val), xytext=(0, 2), textcoords='offset points')
plt.show()

# %%
plt.bar(count_by_subject.index, count_by_subject.values, width=0.7, color='blue')
plt.title('Books by subject')
plt.xlabel('subject')
plt.ylabel('number of books')
for idx, val in count_by_subject.items():
    plt.annotate(val, (idx, val), xytext=(0, 2), textcoords='offset points',
                 fontsize=8, ha='center', color='green')
plt.show()

# %%
plt.barh(count_by_subject.index, count_by_subject.values, height=0.7, color='blue')
plt.title('Books by subject')
plt.xlabel('number of books')
plt.ylabel('subject')
for idx, val in count_by_subject.items():
    plt.annotate(val, (val, idx), xytext=(2, 0), textcoords='offset points',
                 fontsize=8, va='center', color='green')
plt.show()

# %%
# 노트북이 코랩에서 실행 중인지 체크합니다.
import sys
if 'google.colab' in sys.modules:
    # 샘플 이미지를 다운로드합니다.
    # !wget https://recipe1.ezmember.co.kr/cache/recipe/2018/01/24/e99c39545162aea048b572167762e61e1.jpg
# Out:
# --2024-09-12 01:25:07--  https://recipe1.ezmember.co.kr/cache/recipe/2018/01/24/e99c39545162aea048b572167762e61e1.jpg
# Resolving recipe1.ezmember.co.kr (recipe1.ezmember.co.kr)... 169.150.230.129, 87.249.136.89
# Connecting to recipe1.ezmember.co.kr (recipe1.ezmember.co.kr)|169.150.230.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 186013 (182K) [image/jpeg]
# Saving to: ‘e99c39545162aea048b572167762e61e1.jpg’
#
# e99c39545162aea048b 100%[===================>] 181.65K  --.-KB/s    in 0.09s
#
# 2024-09-12 01:25:08 (2.04 MB/s) - ‘e99c39545162aea048b572167762e61e1.jpg’ saved [186013/186013]

# %%
img = plt.imread('/content/e99c39545162aea048b572167762e61e1.jpg')
img.shape
# Out:
# (800, 800, 3)

# %%
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from PIL import Image

plt_img = Image.open('/content/e99c39545162aea048b572167762e61e1.jpg')
plt.figure(figsize=(8, 6))
plt.imshow(plt_img)
plt.axis('off')
plt.show()

# %%
import numpy as np

arr_img = np.array(plt_img)
arr_img.shape
# Out:
# (800, 800, 3)

# %%
plt.imsave('jupiter.jpg', arr_img)

# %%
plt.rcParams['savefig.dpi']
# Out:
# 'figure'

# %% [markdown]
# 그래프를 만ㄴ들고 이미지로 저장해버리려면...

# %%
plt.barh(count_by_subject.index, count_by_subject.values, height=0.7, color='blue')
plt.title('Books by subject')
plt.xlabel('number of books')
plt.ylabel('subject')
for idx, val in count_by_subject.items():
    plt.annotate(val, (val, idx), xytext=(2, 0), textcoords='offset points',
                 fontsize=8, va='center', color='green')
plt.savefig('books_by_subject.png')
plt.show()

# %%
plt_img = Image.open("books_by_subject.png")
plt.figure(figsize=(8,6))
plt.imshow(plt_img)
plt.axis('off')
plt.show()
